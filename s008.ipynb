# %% [markdown]
# # Largest Product in a Series
# Source: https://projecteuler.net/problem=8
# (date: 8/20/19)

# %% [markdown]
# ## Problem Statement
# Find the largest product of 13 consecutive digits in the 1000-digit number:
#
# 73167176531330624919225119674426574742355349194934
# 96983520312774506326239578318016984801869478851843
# 85861560789112949495459501737958331952853208805511
# 12540698747158523863050715693290963295227443043557
# 66896648950445244523161731856403098711121722383113
# 62229893423380308135336276614282806444486645238749
# 30358907296290491560440772390713810515859307960866
# 70172427121883998797908792274921901699720888093776
# 65727333001053367881220235421809751254540594752243
# 52584907711670556013604839586446706324415722155397
# 53697817977846174064955149290862569321978468622482
# 83972241375657056057490261407972968652414535100474
# 82166370484403199890008895243450658541227588666881
# 16427171479924442928230863465674813919123162824586
# 17866458359124566529476545682848912883142607690042
# 24219022671055626321111109370544217506941658960408
# 07198403850962455444362981230987879927244284909188
# 84580156166097919133875499200524063689912560717606
# 05886116467109405077541002256983155200055935729725
# 71636269561882670428252483600823257530420752963450

# %% [markdown]
# ## Planning
# Calculate every 13 adjacent digit product, swap the largest one each time.
#
# Avoid redundancy by keeping track of the first digit, the last digit, and the running product.
#
# Be careful with fencepost errors
#
# edit: this doesn't work because there may be `0` digits

# %% [markdown]
# ## [work]

# %%
large_number = ...

print(large_number)
# Out:
# ...

# %%
def largest_13_product(number):
    
    # check that number has enough digits
    
    # claculate initial running product
    
    
    # get first and last digit of current running product
    
    # update, compar
    
    # return largest product

# %%
large_number_string = "..."

print(large_number_string)
# Out:
# ...

# %%
length = 13

biggest_product = 0
biggest_product_start = 0

for i in range(0, len(large_number_string) + 1 - length):
    
    product = 1
    for j in range(13):
        product *= int(large_number_string[i+j])
        
    if product > biggest_product: 
        biggest_product = product
        biggest_product_start = i
        
print(biggest_product)
print(f"at index {biggest_product_start}")
# Out:
# 23514624000
# at index 197

# %%
print(large_number_string[197 : (197+13)])
# Out:
# 5576689664895
